# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime as dt

# %%
df = pd.read_csv("Crime_Reports (1).csv")
df
# Out:
# C:\Users\lordw\AppData\Local\Temp\ipykernel_23324\3717847652.py:1: DtypeWarning: Columns (16,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Crime_Reports (1).csv")
#          Incident Number  Highest Offense Description  Highest Offense Code  \
# 0            20072790876          DISTURBANCE - OTHER                  3401
# 1            20065065520                FRAUD - OTHER                  1199
# 2          2003421480455  CUSTODY ARREST TRAFFIC WARR                  3722
# 3            20052602038       DOC UNREASONABLE NOISE                  2405
# 4            20065065524                FRAUD - OTHER                  1199
# ...                  ...                          ...                   ...
# 2397737      20173630952           FAMILY DISTURBANCE                  3400
# 2397738      20135014041          BURGLARY OF VEHICLE                   601
# ...

# %%
def p_unique_col_values(df):
     for column in df:
          if df[column].dtypes == 'object':
               print(f'{column} : {df[column].unique()}')

# %%
p_unique_col_values(df)
# Out:
# Highest Offense Description : ['DISTURBANCE - OTHER' 'FRAUD - OTHER' 'CUSTODY ARREST TRAFFIC WARR'
#  'DOC UNREASONABLE NOISE' 'PROTECTIVE ORDER' 'FAMILY DISTURBANCE'
#  'IDENTITY THEFT' 'RAPE' 'INDECENCY WITH A CHILD/CONTACT' 'THEFT'
#  'ASSAULT  CONTACT-SEXUAL NATURE' 'HARASSMENT' 'FORGERY OF IDENTIFICATION'
#  'EXPLOSIVE ORDNANCE DISPOSAL' 'AGG SEXUAL ASSAULT CHILD/OBJEC'
#  'FAILURE TO REG AS SEX OFFENDER' 'WARRANT ARREST NON TRAFFIC'
#  'VIOL OF PROTECTIVE ORDER' 'SEXUAL ASSAULT OF CHILD/OBJECT'
#  'TERRORISTIC THREAT' 'BURG OF RES - SEXUAL NATURE' 'GRAFFITI'
#  'CHILD CUSTODY INTERFERE' 'THEFT FROM PERSON' 'PUBLIC LEWDNESS'
#  'FORCED SODOMY' 'INDECENT EXPOSURE' 'BREACH OF COMPUTER SECURITY'
#  'AGG RAPE OF A CHILD' 'AGG ROBBERY/DEADLY WEAPON'
#  'SEXUAL ASSAULT W/ OBJECT' 'BURGLARY OF VEHICLE'
#  'STATUTORY RAPE OF CHILD' 'ASSAULT WITH INJURY'
#  'INVASIVE VISUAL RECORDING' 'ASSAULT W/INJURY-FAM/DATE VIOL'
#  'POSS SYNTHETIC MARIJUANA' 'INJURY TO CHILD' 'RAPE OF A CHILD'
# ...

# %%
df['Report Time'] = pd.to_numeric(df['Report Time'])

# %%
crimes = ['DISTURBANCE - OTHER', 'FRAUD - OTHER', 'CUSTODY ARREST TRAFFIC WARR',
 'DOC UNREASONABLE NOISE', 'PROTECTIVE ORDER', 'FAMILY DISTURBANCE',
 'IDENTITY THEFT' 'RAPE' 'INDECENCY WITH A CHILD/CONTACT' 'THEFT',
'ASSAULT  CONTACT-SEXUAL NATURE' 'HARASSMENT' 'FORGERY OF IDENTIFICATION'
 'EXPLOSIVE ORDNANCE DISPOSAL' 'AGG SEXUAL ASSAULT CHILD/OBJEC'
 'FAILURE TO REG AS SEX OFFENDER' 'WARRANT ARREST NON TRAFFIC'
 'VIOL OF PROTECTIVE ORDER' 'SEXUAL ASSAULT OF CHILD/OBJECT'
 'TERRORISTIC THREAT' 'BURG OF RES - SEXUAL NATURE' 'GRAFFITI'
 'CHILD CUSTODY INTERFERE' 'THEFT FROM PERSON' 'PUBLIC LEWDNESS'
 'FORCED SODOMY' 'INDECENT EXPOSURE' 'BREACH OF COMPUTER SECURITY'
 'AGG RAPE OF A CHILD' 'AGG ROBBERY/DEADLY WEAPON'
 'SEXUAL ASSAULT W/ OBJECT' 'BURGLARY OF VEHICLE'
 'STATUTORY RAPE OF CHILD' 'ASSAULT WITH INJURY'
 'INVASIVE VISUAL RECORDING' 'ASSAULT W/INJURY-FAM/DATE VIOL'
 'POSS SYNTHETIC MARIJUANA' 'INJURY TO CHILD' 'RAPE OF A CHILD'
 'ENTICING A CHILD' 'AGG ASLT STRANGLE/SUFFOCATE' 'CRUELTY TO ANIMALS'
 'BURGLARY NON RESIDENCE' 'CRIMINAL MISCHIEF' 'CRIMINAL TRESPASS'
 'FEDERAL VIOL/OTHER' 'AGG RAPE' 'TRAFFICKING OF PERSONS'
 'ASSAULT BY CONTACT FAM/DATING' 'CONT SEX ABUSE OF CHILD'
 'CRED CARD ABUSE - OTHER' 'AGG ASSAULT' 'DISCLOSE/PROMO INTIMATE VISUAL'
 'ASSAULT BY CONTACT' 'FORCED SODOMY OF CHILD'
 'INCEST-PROHIBITED SEX CONDUCT' 'FELONY ENHANCEMENT/ASSLT W/INJ'
 'THEFT BY EMBEZZLEMENT' 'KIDNAPPING' 'FORGERY - OTHER'
 'POSSESSION OF MARIJUANA' 'PROSTITUTION' 'INDECENCY WITH CHILD/EXPOSURE'
 'FALSE STATEMENT -OBTAIN CREDIT' 'DATING DISTURBANCE'
 'VIOL STATE LAW - OTHER' 'CRED CARD ABUSE BY FORGERY' 'THEFT OF SERVICE'
 'BURGLARY OF RESIDENCE' 'CRIMINAL SOLICITATION OF MINOR'
 'VIOL OF EMERG PROTECTIVE ORDER' 'ONLINE IMPERSONATION'
 'UNLAWFUL CARRYING WEAPON' 'DEPENDENT AND NEGLECTED CHILD'
 'ASSAULT BY THREAT' 'ONLINE SOLICITATION OF A MINOR'
 'POSS/PROMO CHILD PORNOGRAPHY' 'VIOL OF PARK CURFEW'
 'PROMOTION OF PROSTITUTION' 'SERIOUS INJURY TO A CHILD'
 'FAMILY DISTURBANCE/PARENTAL' 'STALKING' 'PROWLER' 'AUTO THEFT'
 'POSS CONTROLLED SUB/NARCOTIC' 'DOC EXPOSURE'
 'VOCO SOLICITATION PROHIBIT' 'AGG ASSAULT FAM/DATE VIOLENCE'
 'DAMAGE CITY PROP' 'DEL MARIJUANA' 'INJURY DISABLED INDIVIDUAL' 'DWI'
 'POSS OF FIREARM BY FELON' 'AGG SEXUAL ASSAULT W OBJECT'
 'TERRORISTIC THREAT-FAM/DAT VIO' 'THEFT BY SHOPLIFTING'
 'POSS OF ALCOHOL - AGE 17 TO 20' 'VIOL OF COURT ORDER-NON EPO-PO'
 'THEFT OF LICENSE PLATE' 'CHILD ENDANGERMENT- ABANDONMEN'
 'THEFT FROM AUTO' 'DEL CONTROLLED SUB/NARCOTIC' 'FAILURE TO IDENTIFY'
 'THEFT OF METAL' 'EVADING / VEHICLE PURSUIT' 'OFFICIAL OPPRESSION'
 'IMPERSONATING PUBLIC SERVANT' 'AGG FORCED SODOMY OF CHILD'
 'SEXUAL PERFORMANCE BY CHILD' 'INJURY TO CHILD (CARE/CUSTODY)'
 'SEXTING DEPICTING A MINOR' 'VIOL CITY ORDINANCE - OTHER'
 'CRIMINAL SOLICITATION' 'UNLAWFUL RESTRAINT' 'DEBIT CARD ABUSE'
 'INTER EMERG PHONECALL FAM/DATE' 'POSS OF DRUG PARAPHERNALIA'
 'OBSCENE DISPLAY - DISTRIBUTION' 'CRIMINAL TRESPASS/TRANSIENT'
 'DOC OFFENSIVE GESTURE' 'AGG KIDNAPPING FAM VIO'
 'EXPIRED-ATT SEXUAL ASSAULT' 'INJURY TO ELDERLY PERSON'
 'APPLIC TO REVOKE PROBATION' 'INDECENT ASSAULT'
 'EXPIRED-INJURY CHILD - ELDERLY' 'BURG OF RES - FAM/DATING ASLT'
 'AGG PROMOTION OF PROSTITUTION' 'GAMBLING' 'AGG ROBBERY BY ASSAULT'
 'INJ TO ELDERLY   FAM/DATE VIOL' 'ASSAULT BY THREAT FAM/DATING'
 'CAMPING IN PARK' 'AGG FORCED SODOMY' 'EVADING / FOOT' 'DEADLY CONDUCT'
 'UNLAWFUL RESTRAINT FAM/DAT VIO' 'ASSAULT ON PUBLIC SERVANT'
 'ROBBERY BY ASSAULT' 'EXPIRED-ATT SEXUAL ASULT CHILD' 'MURDER'
 'FALSE REPORT TO PEACE OFFICER' 'AGG ASLT ENHANC STRANGL/SUFFOC'
 'PAROLE VIOL' 'INJ TO DISABLED  FAM/DATE VIOL' 'MONEY LAUNDERING'
 'DAMAGE CITY VEHICLE' 'VIOL WATER SAFETY ACT'
 'CRASH/FAIL STOP AND RENDER AID' 'IMPROPER CONTACT-SEX ASLT VICT'
 'THEFT OF BICYCLE' 'EVADING VEHICLE' 'ROBBERY BY THREAT'
 'DOC ABUSE OR THREAT' 'AGG ASLT W/MOTOR VEH FAM/DAT V'
 'EXPIRED-ATT KIDNAPPING' 'VOCO - ALCOHOL  CONSUMPTION' 'AGG KIDNAPPING'
 'SOLICITATION - BEGGING' 'LIQUOR LAW VIOLATION/OTHER'
 'VOCO AMPLIFIED MUSIC/VEHICLE' 'DWI 2ND' 'URINATING IN PUBLIC PLACE'
 'DWI - DRUG RECOGNITION EXPERT' 'BURGLARY OF VEH-NO SUSPECT/FU'
 'DOC WINDOW PEEPING - HOTEL' 'TAMPERING WITH CONSUMER PROD'
 'BOATING WHILE INTOXICATED' 'FORGERY AND PASSING' 'ATT THEFT'
 'COUNTERFEITING' 'POSS CONTROLLED SUB/SYN NARC'
 'POSS CONTROLLED SUB/OTHER' 'THEFT OF HEAVY EQUIPMENT'
 'RESISTING ARREST OR SEARCH' 'TAMPERING WITH EVIDENCE'
 'HARASSMENT OF A PUBLIC SERVANT' 'DWI  .15 BAC OR ABOVE'
 'VIOL OF BOND CONDITIONS' 'OBSCENITY' 'OBTAIN CONTROLLED SUB BY FRAUD'
 'SIT AND LIE ORDINANCE VIOL' 'DISRUPTION OF CLASSES'
 'DOC DISCHARGE GUN - PUB ROAD' 'VIOL CITY ORDINANCE - TAXI'
 'DUI - AGE 17 TO 20' 'DOC ABUSIVE LANGUAGE' 'LITTERING'
 'DISTRIB HARMFUL MATERIAL MINOR' 'DOC FIGHTING'
 'CRIMINAL TRESPASS/IN VEHICLE' 'THEFT OF TELECOMMUNICATION SRV'
 'HARBORING RUNAWAY CHILD' 'CRIMINAL TRESPASS/HOTEL' 'MAIL THEFT'
 'FALSE ALARM OR REPORT' 'THEFT OF AUTO PARTS' 'RECKLESS DAMAGE'
 'SLEEPING IN PUBLIC PLACE' 'DUMPING REFUSE NEAR HIGHWAY'
 'EXPIREDATT AGG SEX ASSLT CHILD' 'FORGERY BY MAKING'
 'AMPLIFIED MUSIC / VEHICLE' 'PERJURY' 'THEFT CATALYTIC CONVERTER'
 'AGG ASSAULT WITH MOTOR VEH' 'IMMIGRATION HOLD/ARREST'
 'INTERFERE W PO SERVICE ANIMALS' 'RETALIATION' 'CONTEMPT OF COURT'
 'TRADEMARK COUNTERFEITING' 'HARASSMENT ONLINE' 'SMUGGLING ILLEGAL ALIEN'
 'POSS OF PROHIBITED WEAPON' 'PROBATION VIOL' 'CIVIL DISTURBANCE/DEMO'
 'ABUSE OF OFFICIAL CAPACITY' 'TAMPERING WITH ID NUMBER'
 'COMPELLING PROSTITUTION' 'HINDERING APPREHENSION'
 'MAKING TOBACCO AVAIL TO MINOR' 'EXPLOITATION OF CHILD/ELDERLY'
 'VIOL CITY ORDINANCE - SMOKING' 'BOMB THREAT'
 'FORGERY- CERTIFICATE OF TITLE' 'ATT BURGLARY OF RESIDENCE'
 'BURGLARY OF COIN-OP MACHINE' 'HAZING'
 'BURGLARY OF SHED/DETACHED GARAGE/STORAGE UNIT'
 'EXPIRED-ATT AGG SEXUAL ASSAULT' 'DOC CREATING NOXIOUS ODOR'
 'SECURING EXEC-DOC BY DECEPTION' 'TAMPERING WITH WITNESS' 'ARSON'
 'EXPIRED-ATTAGGFORCESODOMYCHILD' 'EXPIRED-ATT FORCED SODOMY'
 'DEL CONTROLLED SUB/SYN NARC' 'THEFT FROM BUILDING'
 'DEL OF ALCOHOL TO MINOR' 'ESCAPE FROM CUSTODY' 'WEAPON VIOL - OTHER'
 'DUI - AGE 16 AND UNDER' 'THEFT- APPROPRIATE STOLEN PROP'
 'EXPIRED-ATT RAPE' 'EXPIRED-ATT RAPE OF A CHILD'
 'VIOL PO / SEXUAL ASLT VICTIM' 'SEXTING/TRANSMIT SEXUAL PHOTOS'
 'CAPITAL MURDER' 'EXPIRED-ATT AGG KIDNAPPING' 'AGG SODOMY'
 'VIOL CITY ORDINANCE - DOG' 'POSS DANG DRUG'
 'DRIVING WHILE INTOX / FELONY' 'DOC DISCHARGE GUN - PUB PLACE'
 'DWI - CHILD PASSENGER' 'KIDNAPPING FAM VIO' 'THEFT BY EXTORTION'
 'AIRPORT PLACES WEAPON PROHIBIT' 'FORGERY BY ALTERATION'
 'DEL CONTROLLED SUB/OTHER' 'EXPIRED-ATT AGG ROBBERY/WEAP'
 'BAIL JUMPING/FAIL TO APPEAR' 'VIOL CITY ORDINANCE - CURFEW'
 'ASSAULT OF PREGNANT WM-FAM/DAT' 'THEFT OF TRAILER'
 'VIOL CITY ORDINANCE - WRECKER' 'DOC DISPLAY GUN/DEADLY PUB PLC'
 'ASSAULT ON PEACE OFFICER' 'VIOL CIVIL RIGHTS PRISONER'
 'TELECOMMUNICATION CRIMES/OTHER' 'DEADLY CONDUCT FAM/DATE VIOL'
 'FAIL TO REGISTER- MINOR VIC' 'VIOL CITY ORDINANCE -FIREWORK'
 'DANG DRUG VIOL - OTHER' 'ILLUMIN AIRCRAFT INTENSE LIGHT'
 'CRIMINAL MISCHIEF-NO SUSPECT' 'CRASH/CRIM NEG HOMICIDE'
 'THEFT-NO SUSPECT/FOLLOWUP' 'VIOL CITY ORDINANCE -  GAME RM'
 'PURSE SNATCHING' 'AGG ASSAULT ON PEACE OFFICER' 'VIOL GLASS CONTAINER'
 'IDENTITY THEFT-TAX RETURNS' 'ATT AUTO THEFT'
 'EXP-VIOL CITY ORDINANCE - TAXI' 'UNLAWFUL CARRY-LIC HOLDER'
 'PIGEON DROP' 'AGG ASSAULT ON PUBLIC SERVANT' 'OBTAIN DANG DRUG BY FRAUD'
 'TOBACCO VIOL - AGE 17' 'MANF CONTROLLED SUB - OTHER' 'FICTITIOUS NAME'
 'NUISANCE ABATEMENT' 'TOBACCO VIOL - UNDER AGE 17'
 'TAMPERING WITH GOV RECORD' 'MANF CONTROLLED SUB- SYN NARC'
 'CRASH/INTOXICATION ASSAULT' 'FRAUD-CARD SKIMMER'
 'POSS OF ALCOHOL-AGE 16 & UNDER' 'ILLEGAL LABELLING OF RECORDING'
 'RENTAL CAR/FAIL TO RETURN' 'INHALANT ABUSE' 'POSS CRIMINAL INSTRUMENT'
 'DEL SYNTHETIC MARIJUANA' 'COMMUNICATING GAMBLING INFO'
 'INTERFERING W/EMERG PHONE CALL' 'UCW LICENSE PREMISE'
 'GAMBLING PROMOTION' 'INTERFERENCE PUBLIC DUTIES'
 'VIOL CITY ORDINANCE - SOUND' 'RIOT' 'SALE OR PURCHASE OF CHILD'
 'RECKLESS CONDUCT' 'FRAUD DESTRUCTION OF A WRITING'
 'TERRORISTIC THREAT-MASS CASLTY' 'FRAUD FILING FINANCE STATEMENT'
 'MISAPPLY FIDUCIARY PROP' 'ASSAULT - SCHOOL PERSONNEL'
 'VIOL STAY AWAY ORDER' 'CONTROLLED SUB VIOL - OTHER'
 'INJ/CHILD FV (NO CARE/CUSTODY)' 'MISREP AGE BY MINOR'
 'HINDER SECURED CREDITORS' 'ABUSE OF 911' 'PURCHASING PROSTITUTION'
 'CRASH/INTOX MANSLAUGHTER' 'CRASH/MANSLAUGHTER' 'TRUANCY'
 'VIOL TEMP EX PARTE  ORDER' 'AGG SEXUAL ASSAULT CHILD/OBJECT-SUPER'
 'INJURY TO ELDERLY PERSON - SBI' 'AIRPORT - CRIMINAL TRESPASS'
 'POCKET PICKING' 'ENGAGING IN ORGANIZED CRIME' 'AIRPORT - FEDERAL VIOL'
 'THEFT BY PUBLIC SERVANT' 'EXPIRED-EVADING ARREST'
 'ATT BURGLARY NON RESIDENCE' 'VIOL CITY ORDINANCE - AIRPORT'
 'LOCATION RESTRICT KNIFE CLS C' 'DESECRATION VENERATED OBJECT'
 'TOBACCO VIOL - UNDER AGE 21' 'BANK KITING' 'FALSE REPORT TO CPS'
 'PRACTICE MEDICINE W/OUT LICENS' 'JUSTIFIED HOMICIDE' 'MANSLAUGHTER'
 'CRIMES AGAINST ELDERLY' 'TAKE WEAPON FRM POLICE OFFICER'
 'ASSAULT OF A PREGNANT WOMAN' 'SEXUAL COERCION'
 'VIOL OF CAMPING ORDINANCE' 'AGG ASSAULT BY PUBLIC SERVANT'
 'THEFT BY FALSE PRETEXT/BUNCO' 'AIRPORT - BREACH OF SECURITY'
 'HINDERING PROCEEDING' 'VIOL CITY ORDINANCE - BOOTING'
 'ARSON-CRIMINAL MISCHIEF' 'ARSON-VIOL CITY ORDINANCE' 'ATTACK BY DOG'
 'ARSON-RECKLESS DAMAGE' 'BRIBERY' 'ARSON-DEADLY CONDUCT' 'CRASH/MURDER'
 'EXPIRED-ATT CAPITAL MURDER' 'VIOL OF OBSTRUCTION ORDINANCE'
 'BWI-EXPIRED USE 2110' 'DISPOSAL OF SOLID WASTE'
 'THEFT OF CRYPTOCURRENCY' 'FIREARMS ON SCHOOL PROP'
 'ABANDONED REFRIGERATOR' 'DELIVERY OF PRESCRIPTION FORM'
 'POSSESSION OF FORGED WRITING' 'MISUSE OF OFFICIAL INFO'
 'CRED CARD ABUSE - EXPIR-CANCEL' 'VIOL OF PRISONERS RIGHT'
 'VIOL CITY ORDINANCE - TITLE 10' 'CRIMINAL CONSPIRACY'
 'THEFT/TILL TAPPING' 'EXPIRED-ATT ROBBERY BY ASSAULT'
 'EXPIRED-ATT OBT CONT SUB FRAUD' 'AWOL' 'ARSON WITH BODILY INJURY'
 'CONTRIBUTE DELINQUENCY MINOR' 'POSS OF GAMBLING PARAPHERNALIA'
 'CRIM NEG HOMICIDE/NON TRAFFIC' 'DISRUPTIVE ACTS AT SCHOOLS'
 'POSS OF PRESCRIPTION FORM' 'VIOL OF AGGRESSIVE CONFRONT'
 'KEEPING GAMBLING PLACE' 'FAIL DISPLAY HANDGUN LICENSE'
 'EXPIRED-ATT MURDER' 'FALSE ID AS A PEACE OFFICER'
 'UNLAWFUL INTERCEPTION' 'DEL OF DANG DRUG' 'ABUSE OF CORPSE'
 'LOITERING ON SCHOOL PROP' 'EXPIRED-ATT/TAKE WEAP FROM OFF'
 'AIDING SUICIDE' 'DESERTION' 'DOMESTIC VIOLENCE/ALARM'
 'DRINKING AFTER CURFEW' 'AIRPORT - BOMB THREAT'
 'POSS OF GAMBLING EQUIPMENT' 'CRIMINAL NONSUPPORT'
 'SALE OF LIQ WITHOUT PERMIT' 'ATT ARSON' 'DISRUPTING MEETING/PROCESSION'
 'OFFICIAL MISCONDUCT' 'BESTIALITY' 'STAY AWAY ORDER' 'COMMERCIAL BRIBERY'
 'SALE OF DXM TO MINOR' 'ATTACK ON ASSISTANCE ANIMAL'
 'EXPIRED-ATT OB DANG DRUG FRAUD' 'VIOL STATE MASSAGE REGULATIONS'
 'COERCION OF PUBLIC SERVANT' 'AGG PERJURY'
 'ILLEGAL TRANSPORTATION OF LIQ' 'FAIL TO REGISTER - ADULT VIC'
 'BOMB THREAT - AIRCRAFT' 'EXPIRED - DEADLY ASSAULT'
 'FAILURE TO REPORT CHILD ABUSE' 'VIOL CITY ORD-COVID 19 MASK'
 'EXPIRED-DO NOT USE-ASSAULT ON PEACE OFFICER'
 'FALSE CALLER ID DISPLAY/SPOOF' 'POSS OF LIQ ON SCHOOL PROP'
 'LOITERING IN PUBLIC PARK' 'SALE OF LIQ IN PROHIB AREA'
 'MANF SYNTHETIC MARIJUANA' 'EXPIRED-SOLICITATION OF CHILD'
 'GIFT TO PUBLIC SERVANT' 'CRASH/NEGLIGENT HOMICIDE']

for i in range(len(crimes)):
    crime = crimes[i]
    plt.hist(df['Report Time'])
    plt.xlabel('Hour Time')
    plt.ylabel("Frequency")
    plt.show()
# Out:
# 1

# %%
df.columns
# Out:
# Index(['Incident Number', 'Highest Offense Description',
#        'Highest Offense Code', 'Family Violence', 'Occurred Date Time',
#        'Occurred Date', 'Occurred Time', 'Report Date Time', 'Report Date',
#        'Report Time', 'Location Type', 'Address', 'Zip Code',
#        'Council District', 'APD Sector', 'APD District', 'PRA', 'Census Tract',
#        'Clearance Status', 'Clearance Date', 'UCR Category',
#        'Category Description', 'X-coordinate', 'Y-coordinate', 'Latitude',
#        'Longitude', 'Location', 'Zip Codes', 'Single Member Council Districts',
#        'BOUNDARIES_single_member_districts', 'Zoning Review Cases_data',
#        'Neighborhood Planning Areas',
#        'Boundaries: City of Austin Council Districts'],
#       dtype='object')

# %%
most_common_value = df['Highest Offense Description'].value_counts().idxmax()

most_common_value
# Out:
# 'BURGLARY OF VEHICLE'

# %%
plt.figure(figsize=(50, 50))
plt.hist(df['Highest Offense Description'])
plt.xlabel('Offense Type')
plt.ylabel('Frequency')
plt.xticks(rotation=90)  # Rotate labels by 45 degrees
plt.show()

# %%
df.dtypes
# Out:
# Incident Number                                   int64
# Highest Offense Description                      object
# Highest Offense Code                              int64
# Family Violence                                  object
# Occurred Date Time                               object
# Occurred Date                                    object
# Occurred Time                                   float64
# Report Date Time                                 object
# Report Date                                      object
# Report Time                                     float64
# Location Type                                    object
# Address                                          object
# Zip Code                                        float64
# Council District                                float64
# APD Sector                                       object
# APD District                                     object
# PRA                                              object
# ...

# %%
df.sample(3)
# Out:
#          Incident Number     Highest Offense Description  \
# 1671505      20135034306             BURGLARY OF VEHICLE
# 54988        20172101517                  COUNTERFEITING
# 17398        20083112501  INDECENCY WITH A CHILD/CONTACT
#
#          Highest Offense Code Family Violence      Occurred Date Time  \
# 1671505                   601               N  07/30/2013 02:45:00 AM
# 54988                    1006               N  07/29/2017 08:44:00 PM
# 17398                    1709               N  11/06/2008 11:32:00 PM
#
#         Occurred Date  Occurred Time        Report Date Time Report Date  \
# 1671505    07/30/2013          245.0  07/30/2013 04:54:00 AM  07/30/2013
# 54988      07/29/2017         2044.0  07/29/2017 08:44:00 PM  07/29/2017
# 17398      11/06/2008         2332.0  11/06/2008 11:32:00 PM  11/06/2008
#
#          Report Time  ... Y-coordinate   Latitude  Longitude  \
# 1671505        454.0  ...   10081412.0  30.296934 -97.720828
# ...

# %%
df.columns
# Out:
# Index(['Incident Number', 'Highest Offense Description',
#        'Highest Offense Code', 'Family Violence', 'Occurred Date Time',
#        'Occurred Date', 'Occurred Time', 'Report Date Time', 'Report Date',
#        'Report Time', 'Location Type', 'Address', 'Zip Code',
#        'Council District', 'APD Sector', 'APD District', 'PRA', 'Census Tract',
#        'Clearance Status', 'Clearance Date', 'UCR Category',
#        'Category Description', 'X-coordinate', 'Y-coordinate', 'Latitude',
#        'Longitude', 'Location', 'Zip Codes', 'Single Member Council Districts',
#        'BOUNDARIES_single_member_districts', 'Zoning Review Cases_data',
#        'Neighborhood Planning Areas',
#        'Boundaries: City of Austin Council Districts'],
#       dtype='object')

# %%
unique_values = df['Highest Offense Description'].unique().tolist()
len(unique_values)
# Out:
# 433

# %%
n = 16
top_common_values = df['Highest Offense Description'].value_counts().head(n)
most_common_values = df['Highest Offense Description'].value_counts().index.tolist()[:n]
most_common_values
# Out:
# ['BURGLARY OF VEHICLE',
#  'THEFT',
#  'FAMILY DISTURBANCE',
#  'CRIMINAL MISCHIEF',
#  'ASSAULT W/INJURY-FAM/DATE VIOL',
#  'BURGLARY OF RESIDENCE',
#  'DWI',
#  'HARASSMENT',
#  'DISTURBANCE - OTHER',
#  'AUTO THEFT',
#  'ASSAULT WITH INJURY',
#  'THEFT BY SHOPLIFTING',
#  'CUSTODY ARREST TRAFFIC WARR',
#  'WARRANT ARREST NON TRAFFIC',
#  'CRIMINAL TRESPASS',
#  'BURGLARY NON RESIDENCE']
